# %%
l = [1,2,4,7]
l.append(["ram","shyam"])
l
# Out:
# [1, 2, 4, 7, ['ram', 'shyam']]

# %%
import copy
l = [6,8,9]
l_new = copy.copy(l)
print(l)
print(l_new)
l.append([77,55,77])
print(l)
print(l_new)
l_new.append([000,7777])
print(l)
print(l_new)
# Out:
# [6, 8, 9]
# [6, 8, 9]
# [6, 8, 9, [77, 55, 77]]
# [6, 8, 9]
# [6, 8, 9, [77, 55, 77]]
# [6, 8, 9, [0, 7777]]
