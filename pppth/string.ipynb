# %%
#The capitalize() method converts the first character of a string to an uppercase letter and all other alphabets to lowercase.

sentence = "i love PYTHON"

# converts first character to uppercase and others to lowercase
capitalized_string = sentence.capitalize()

print(capitalized_string)

# Output: I love python
# Out:
# I love python

# %% [markdown]
# | **Method**                                     | **Description**                                                                      |
# | ---------------------------------------------- | ------------------------------------------------------------------------------------ |
# | `capitalize()`                                 | Converts the first character to uppercase and the rest to lowercase.                 |
# | `casefold()`                                   | Converts string to lowercase, more aggressive than `lower()` (handles Unicode).      |
# | `center(width, fillchar=' ')`                  | Returns a centered string of given width, padded with `fillchar`.                    |
# | `count(substring, start=0, end=len(string))`   | Returns the number of non-overlapping occurrences of a substring.                    |
# | `encode(encoding='utf-8', errors='strict')`    | Returns an encoded version of the string.                                            |
# | `endswith(suffix, start=0, end=len(string))`   | Returns `True` if the string ends with the specified suffix.                         |
# | `expandtabs(tabsize=8)`                        | Replaces tab characters `\t` with spaces.                                            |
# | `find(sub, start=0, end=len(string))`          | Returns the lowest index of substring; returns `-1` if not found.                    |
# | `format(*args, **kwargs)`                      | Performs string formatting with placeholders `{}`.                                   |
# | `format_map(mapping)`                          | Similar to `format()`, but takes a dictionary directly.                              |
# | `index(sub, start=0, end=len(string))`         | Like `find()`, but raises `ValueError` if substring not found.                       |
# | `isalnum()`                                    | Returns `True` if all characters are alphanumeric.                                   |
# | `isalpha()`                                    | Returns `True` if all characters are alphabetic.                                     |
# | `isascii()`                                    | Returns `True` if all characters are ASCII.                                          |
# | `isdecimal()`                                  | Returns `True` if all characters are decimal digits.                                 |
# | `isdigit()`                                    | Returns `True` if all characters are digits.                                         |
# | `isidentifier()`                               | Returns `True` if string is a valid Python identifier.                               |
# | `islower()`                                    | Returns `True` if all characters are lowercase.                                      |
# | `isnumeric()`                                  | Returns `True` if all characters are numeric.                                        |
# | `isprintable()`                                | Returns `True` if all characters are printable.                                      |
# | `isspace()`                                    | Returns `True` if all characters are whitespace.                                     |
# | `istitle()`                                    | Returns `True` if string follows title case.                                         |
# | `isupper()`                                    | Returns `True` if all characters are uppercase.                                      |
# | `join(iterable)`                               | Joins elements of an iterable into one string, separated by the string calling it.   |
# | `ljust(width, fillchar=' ')`                   | Returns a left-justified string of given width.                                      |
# | `lower()`                                      | Converts all characters to lowercase.                                                |
# | `lstrip(chars=None)`                           | Returns a copy of string with leading characters removed.                            |
# | `maketrans(x, y=None, z=None)`                 | Returns a translation table usable by `translate()`.                                 |
# | `partition(sep)`                               | Splits string into a tuple `(head, sep, tail)` at the first occurrence of separator. |
# | `removeprefix(prefix)`                         | Returns string with given prefix removed, if present.                                |
# | `removesuffix(suffix)`                         | Returns string with given suffix removed, if present.                                |
# | `replace(old, new, count=-1)`                  | Returns a string with all (or first `count`) occurrences of substring replaced.      |
# | `rfind(sub, start=0, end=len(string))`         | Returns highest index of substring; returns `-1` if not found.                       |
# | `rindex(sub, start=0, end=len(string))`        | Like `rfind()`, but raises `ValueError` if not found.                                |
# | `rjust(width, fillchar=' ')`                   | Returns a right-justified string of given width.                                     |
# | `rpartition(sep)`                              | Splits string into a tuple `(head, sep, tail)` at the last occurrence of separator.  |
# | `rsplit(sep=None, maxsplit=-1)`                | Splits string from the right by the separator.                                       |
# | `rstrip(chars=None)`                           | Returns a copy of string with trailing characters removed.                           |
# | `split(sep=None, maxsplit=-1)`                 | Splits string into list using given separator (defaults to whitespace).              |
# | `splitlines(keepends=False)`                   | Splits string at line breaks (`\n`, `\r\n`, etc.).                                   |
# | `startswith(prefix, start=0, end=len(string))` | Returns `True` if the string starts with the specified prefix.                       |
# | `strip(chars=None)`                            | Removes leading and trailing characters (default is whitespace).                     |
# | `swapcase()`                                   | Swaps the case of all characters.                                                    |
# | `title()`                                      | Converts string to title case (first letter uppercase, rest lowercase).              |
# | `translate(table)`                             | Translates string using a translation table created by `maketrans()`.                |
# | `upper()`                                      | Converts all characters to uppercase.                                                |
# | `zfill(width)`                                 | Pads string on the left with zeros to make given width.                              |

# %% [markdown]
# | **Category**               | **Examples**                                                                   |
# | -------------------------- | ------------------------------------------------------------------------------ |
# | **Case Conversion**        | `lower()`, `upper()`, `capitalize()`, `title()`, `swapcase()`, `casefold()`    |
# | **Validation (is...)**     | `isalnum()`, `isalpha()`, `isdigit()`, `isspace()`, `isidentifier()`, etc.     |
# | **Search/Find**            | `find()`, `rfind()`, `index()`, `rindex()`, `startswith()`, `endswith()`       |
# | **Replace/Split/Join**     | `replace()`, `split()`, `rsplit()`, `join()`, `partition()`                    |
# | **Trim/Padding**           | `strip()`, `lstrip()`, `rstrip()`, `ljust()`, `rjust()`, `center()`, `zfill()` |
# | **Formatting**             | `format()`, `format_map()`, `translate()`                                      |
# | **Prefix/Suffix Handling** | `removeprefix()`, `removesuffix()`                                             |
