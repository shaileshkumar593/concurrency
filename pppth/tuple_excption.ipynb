# %%
"""What is Tuple?
Ordered

Immutable

Allows duplicates

Hashable (if all elements hashable)"""

t = (1, 2, 3)
t1 = 1,2
print(type(t))
print(type(t1))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
# TypeError (modification attempt)
t[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 # TypeError (modification attempt)
# ----> 2 t[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
#If tuple contains list:

t = ([1,2], 3)
#Tuple becomes unhashable

hash(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 6
#       3 t = ([1,2], 3)
#       4 #Tuple becomes unhashable
# ----> 6 hash(t)
#
# TypeError: unhashable type: 'list'

# %%
t = 5,8,9
hash(t)
# Out:
# -211338518782401183
