# %%
counter = 0

while counter  <  2:
    print('This is inside loop')
    counter = counter + 1
else:
    print('This is inside else block')
# Out:
# This is inside loop
# This is inside loop
# This is inside else block

# %%
import random

random.seed(42) # Use any integer value as a seed
print(random.randint(1, 100))
print(random.randint(1, 100))

random.seed(42) # Resetting the seed produces the same sequence
print(random.randint(1, 100))
# Out:
# 82
# 15
# 82
